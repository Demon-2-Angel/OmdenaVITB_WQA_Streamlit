# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# ''

# %%
df = pd.read_csv(r"/content/temperature.csv")

# %%
df.head()
df.drop(["PARAMETER"], axis=1)
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1981  31.37  35.51  39.90  43.30  44.55  45.49  33.22  30.62  32.23
# 1    1982  28.61  29.15  39.84  41.19  42.44  44.00  39.14  30.69  32.03
# 2    1983  30.63  34.62  38.79  44.12  43.90  44.60  37.60  32.01  30.96
# 3    1984  29.86  31.61  42.34  43.23  46.00  45.23  36.41  31.16  31.19
# 4    1985  31.17  37.30  40.11  43.12  45.23  42.94  37.52  30.99  32.19
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 115  2016  28.04  26.17  25.01  22.41  22.27  20.51   9.50   9.19  10.64
# 116  2017  28.29  27.28  31.25  25.23  21.85  20.76  13.95   9.75  13.38
# 117  2018  24.47  23.70  25.06  24.66  20.66  21.14  13.23   9.52  11.39
# 118  2019  27.35  30.28  31.33  25.75  20.51  22.30  13.22   9.69  10.48
# 119  2020  25.91  27.44  25.92  23.66  20.23  18.96  11.11  10.27  12.12
#
#        OCT    NOV    DEC    ANN
# 0    32.04  29.77  28.01  45.49
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = df._convert(numeric=True)
df.head(20)
df.dtypes
# Out:
# PARAMETER     object
# YEAR           int64
# JAN          float64
# FEB          float64
# MAR          float64
# APR          float64
# MAY          float64
# JUN          float64
# JUL          float64
# AUG          float64
# SEP          float64
# OCT          float64
# NOV          float64
# DEC          float64
# ANN          float64
# dtype: object

# %%
sns.set_theme(style="darkgrid")

# %%
df_value1 = df[['YEAR', 'ANN']]
sns.lineplot(data=df_value1, x='YEAR', y='ANN')
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='ANN'>

# %%
df_melted = pd.melt(df, id_vars=['YEAR'], value_vars=['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'], var_name='MONTH', value_name='TEMPERATURE')
sns.set_theme(style="darkgrid")
# plot the time series
sns.lineplot(data=df_melted, x='YEAR', y='TEMPERATURE', hue="MONTH")
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='TEMPERATURE'>
